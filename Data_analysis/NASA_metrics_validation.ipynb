# %% [markdown]
# # Import and/or install libraries:

# %%
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read data

# %%
# NASA data:
NASA_data_512 = np.loadtxt("../Data/NASA_workshop_validation/C3.3_datafiles/spectral_Re1600_512.gdiag")
time_NASA_512 = NASA_data_512[:, 0]
energy_NASA_512 = NASA_data_512[:, 1] 
dissipation_rate_NASA_512 = NASA_data_512[:, 2]
enstrophy_NASA_512 = NASA_data_512[:, 3]

# 64^3 data:
energy_data_64 = np.loadtxt("../Data/metrics_64/energy_timeseries.txt")
enstrophy_data_64 = np.loadtxt("../Data/metrics_64/enstrophy_timeseries.txt")
dissipation_rate_64 = np.column_stack((energy_data_64[:, 0], 
                                       -np.gradient(energy_data_64[:, 1], energy_data_64[:, 0])))

# 64^3 data with 1024^3 timestep:
energy_data_64_timestep_1024 = np.loadtxt("../Data/metrics_64_timestep_1024/energy_timeseries.txt")
enstrophy_data_64_timestep_1024 = np.loadtxt("../Data/metrics_64_timestep_1024/enstrophy_timeseries.txt")
dissipation_rate_64_timestep_1024 = np.column_stack((energy_data_64_timestep_1024[:, 0], 
                                       -np.gradient(energy_data_64_timestep_1024[:, 1], energy_data_64_timestep_1024[:, 0])))

# 128^3 data:
energy_data_128 = np.loadtxt("../Data/metrics_128/energy_timeseries.txt")
enstrophy_data_128 = np.loadtxt("../Data/metrics_128/enstrophy_timeseries.txt")
dissipation_rate_128 = np.column_stack((energy_data_128[:, 0], 
                                       -np.gradient(energy_data_128[:, 1], energy_data_128[:, 0])))

# 128^3 data with 1024^3 timestep:
energy_data_128_timestep_1024 = np.loadtxt("../Data/metrics_128_timestep_1024/energy_timeseries.txt")
enstrophy_data_128_timestep_1024 = np.loadtxt("../Data/metrics_128_timestep_1024/enstrophy_timeseries.txt")
dissipation_rate_128_timestep_1024 = np.column_stack((energy_data_128_timestep_1024[:, 0], 
                                       -np.gradient(energy_data_128_timestep_1024[:, 1], energy_data_128_timestep_1024[:, 0])))

# 256^3 data:
energy_data_256 = np.loadtxt("../Data/metrics_256/energy_timeseries.txt")
enstrophy_data_256 = np.loadtxt("../Data/metrics_256/enstrophy_timeseries.txt")
dissipation_rate_256 = np.column_stack((energy_data_256[:, 0], 
                                       -np.gradient(energy_data_256[:, 1], energy_data_256[:, 0])))

# 512^3 data:
energy_data_512 = np.loadtxt("../Data/metrics_512/energy_timeseries.txt")
enstrophy_data_512 = np.loadtxt("../Data/metrics_512/enstrophy_timeseries.txt")
dissipation_rate_512 = np.column_stack((energy_data_512[:, 0], 
                                       -np.gradient(energy_data_512[:, 1], energy_data_512[:, 0])))

# %% [markdown]
# # Energy:

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

plt.plot(energy_data_64[:, 0], energy_data_64[:, 1], label='Energy (64x64)', color='C0', linewidth=2.5)
plt.plot(energy_data_128[:, 0], energy_data_128[:, 1], label='Energy (128x128)', color='C1', linewidth=2.5)
plt.plot(energy_data_256[:, 0], energy_data_256[:, 1], label='Energy (256x256)', color='C2', linewidth=2.5)
plt.plot(energy_data_512[:, 0], energy_data_512[:, 1], label='Energy (512x512)', color='C3', linewidth=2.5)
plt.plot(time_NASA_512, energy_NASA_512, label='Energy (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Enstrophy')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

plt.plot(energy_data_64[:, 0], energy_data_64[:, 1], label='Energy (64x64)', color='C0', linewidth=2.5)
plt.plot(energy_data_128[:, 0], energy_data_128[:, 1], label='Energy (128x128)', color='C1', linewidth=2.5)
plt.plot(energy_data_256[:, 0], energy_data_256[:, 1], label='Energy (256x256)', color='C2', linewidth=2.5)
plt.plot(energy_data_512[:, 0], energy_data_512[:, 1], label='Energy (512x512)', color='C3', linewidth=2.5)
plt.plot(time_NASA_512, energy_NASA_512, label='Energy (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Enstrophy')

plt.xlim(0, 10) 
plt.legend()
plt.show()

# %% [markdown]
# # Enstrophy

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

plt.plot(enstrophy_data_64[:, 0], enstrophy_data_64[:, 1], label='Enstrophy (64x64)', color='C0', linewidth=2.5)
plt.plot(enstrophy_data_128[:, 0], enstrophy_data_128[:, 1], label='Enstrophy (128x128)', color='C1', linewidth=2.5)
plt.plot(enstrophy_data_256[:, 0], enstrophy_data_256[:, 1], label='Enstrophy (256x256)', color='C2', linewidth=2.5)
plt.plot(enstrophy_data_512[:, 0], enstrophy_data_512[:, 1], label='Enstrophy (512x512)', color='C3', linewidth=2.5)
plt.plot(time_NASA_512, enstrophy_NASA_512, label='Energy (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Enstrophy')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

plt.plot(enstrophy_data_64[:, 0], enstrophy_data_64[:, 1], label='Enstrophy (64x64)', color='C0', linewidth=2.5)
plt.plot(enstrophy_data_128[:, 0], enstrophy_data_128[:, 1], label='Enstrophy (128x128)', color='C1', linewidth=2.5)
plt.plot(enstrophy_data_256[:, 0], enstrophy_data_256[:, 1], label='Enstrophy (256x256)', color='C2', linewidth=2.5)
plt.plot(enstrophy_data_512[:, 0], enstrophy_data_512[:, 1], label='Enstrophy (512x512)', color='C3', linewidth=2.5)
plt.plot(time_NASA_512, enstrophy_NASA_512, label='Energy (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Enstrophy')

plt.xlim(0, 10) 
plt.legend()
plt.show()

# %% [markdown]
# # Energy dissipation:

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

plt.plot(dissipation_rate_64[:, 0], dissipation_rate_64[:, 1], label='Dissipation Rate (64x64)', color='C0', linewidth=2.5)
plt.plot(dissipation_rate_128[:, 0], dissipation_rate_128[:, 1], label='Dissipation Rate (128x128)', color='C1', linewidth=2.5)
plt.plot(dissipation_rate_256[:, 0], dissipation_rate_256[:, 1], label='Dissipation Rate (256x256)', color='C2', linewidth=2.5)
plt.plot(dissipation_rate_512[:, 0], dissipation_rate_512[:, 1], label='Dissipation Rate (512x512)', color='C3', linewidth=2.5)
plt.plot(time_NASA_512, dissipation_rate_NASA_512, label='Dissipation Rate (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Dissipation Rate')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

plt.plot(dissipation_rate_64[:, 0], dissipation_rate_64[:, 1], label='Dissipation Rate (64x64)', color='C0', linewidth=2.5)
plt.plot(dissipation_rate_128[:, 0], dissipation_rate_128[:, 1], label='Dissipation Rate (128x128)', color='C1', linewidth=2.5)
plt.plot(dissipation_rate_256[:, 0], dissipation_rate_256[:, 1], label='Dissipation Rate (256x256)', color='C2', linewidth=2.5)
plt.plot(dissipation_rate_512[:, 0], dissipation_rate_512[:, 1], label='Dissipation Rate (512x512)', color='C3', linewidth=2.5)
plt.plot(time_NASA_512, dissipation_rate_NASA_512, label='Dissipation Rate (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Dissipation Rate')

plt.xlim(0, 10)
plt.legend()
plt.show()

# %% [markdown]
# # Comparison of the impact of different temporal resolutions on the metrics:

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

#data_1 = energy_data_64
#data_2 = energy_data_64_timestep_1024

data_1 = energy_data_128
data_2 = energy_data_128_timestep_1024

plt.plot(data_1[:, 0], data_1[:, 1], label='Energy', color='C0', linewidth=2.5)
plt.plot(data_2[:, 0], data_2[:, 1], label='Energy (timestep 1024)', color='C4', linewidth=2.5)
plt.plot(time_NASA_512, energy_NASA_512, label='Energy (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Enstrophy')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

#data_1 = enstrophy_data_64
#data_2 = enstrophy_data_64_timestep_1024

data_1 = enstrophy_data_128
data_2 = enstrophy_data_128_timestep_1024

plt.plot(data_1[:, 0], data_1[:, 1], label='Enstrophy (64x64)', color='C0', linewidth=2.5)
plt.plot(data_2[:, 0], data_2[:, 1], label='Enstrophy (64x64, timestep 1024)', color='C4', linewidth=2.5)
plt.plot(time_NASA_512, enstrophy_NASA_512, label='Energy (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Enstrophy')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(6.4, 4.8), dpi=150)

#data_1 = dissipation_rate_64
#data_2 = dissipation_rate_64_timestep_1024

data_1 = dissipation_rate_128
data_2 = dissipation_rate_128_timestep_1024

plt.plot(data_1[:, 0], data_1[:, 1], label='Dissipation Rate', color='C0', linewidth=2.5)
plt.plot(data_2[:, 0], data_2[:, 1], label='Dissipation Rate (timestep 1024)', color='C4', linewidth=2.5)
plt.plot(time_NASA_512, dissipation_rate_NASA_512, label='Dissipation Rate (512x512)', color='k', linewidth=2.5, linestyle='--', alpha=0.6)

plt.xlabel('Timestep')
plt.ylabel('Dissipation Rate')

plt.legend()
plt.show()
